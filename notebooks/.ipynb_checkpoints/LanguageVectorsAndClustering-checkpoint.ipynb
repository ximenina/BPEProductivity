# %%
# %matplotlib widget
import os
import sys
from re import sub
import numpy as np
from collections import defaultdict, Counter
#from nltk.util import ngrams
from random import sample
from itertools import chain
import pandas as pd
#import seaborn as sb

import sklearn

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 6]
from pandas import DataFrame

from sklearn import metrics

# %%
directory="../results/corpusPBCtok200_tsv/"  #tsv directory 
output="corpusPBCtok200_vectors.csv"                  #for storing the resulting centered and scaled datapoints

# %% [markdown]
# Histograms (centered and scale data)

# %%
all_files = os.listdir(directory)

df_avg = pd.DataFrame(columns = ['file', 'word_types', 'cum_freq', 'idiosincracy_index'])

for n in all_files:
	inputcorpus=directory+n
	data = pd.read_csv(inputcorpus,  sep='\t')
	#print ("Processing"+n)

	fileparts=n.split(".")
	isocode=fileparts[0].split("-")

	x = data['word_types'].mean()
	y = data['cum_freq'].mean()
	z = data['idiosincracy_index'].mean()

	df_aux = pd.DataFrame([[isocode[0], x,y,z]], columns=['file', 'word_types', 'cum_freq', 'idiosincracy_index'])
	df_avg=df_avg.append(df_aux)

#print(df_avg.describe())
df_isocodes=df_avg.iloc[:, 0:1] 
df_isocodes=df_isocodes.reset_index(drop=True)


df_avg.columns = range(df_avg.shape[1]) #remove header
df_avg = df_avg.iloc[: , 1:]  #remove first column

# perform a robust scaler transform of the dataset
trans = StandardScaler()
data = trans.fit_transform(df_avg)
# convert the array back to a dataframe
df_data= DataFrame(data)
df_avg_transformed=df_isocodes.join(df_data)
df_avg_transformed.rename(columns={0:'word_types',
                          1:'cum_freq',
                          2:'idiosincracy_index'}, 
                 inplace=True)
#df_avg_transformed = pd.DataFrame([[df_isocodes,df_data]])
#df_avg_transformed.hist()
# summarize
df_avg_transformed.hist()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# array([[<AxesSubplot:title={'center':'word_types'}>,
#         <AxesSubplot:title={'center':'cum_freq'}>],
#        [<AxesSubplot:title={'center':'idiosincracy_index'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
data = pd.read_csv(inputcorpus,  sep='\t')
data
# Out:
#          subword  word_types  cum_freq  idiosincracy_index
# 0             aa        1170      3563            3.045299
# 1         aa</w>         534      2690            5.037453
# 2             ee         619      2064            3.334410
# 3             dh         488      1883            3.858607
# 4             is         230      1909            8.300000
# ..           ...         ...       ...                 ...
# 195     kana</w>           3        84           28.000000
# 196          kun           3        83           27.666667
# 197  wajjiin</w>           1        82           82.000000
# 198   keeysa</w>           1        82           82.000000
# 199       deebis          11        82            7.454545
#
# [200 rows x 4 columns]

# %%
all_files = os.listdir(directory)

df_avg = pd.DataFrame(columns = ['file', 'word_types', 'cum_freq', 'idiosincracy_index'])

for n in all_files:
	inputcorpus=directory+n
	data = pd.read_csv(inputcorpus,  sep='\t')
	#print ("Processing"+n)

	fileparts=n.split(".")
	isocode=fileparts[0].split("-")

	x = data['word_types'].mean()
	y = data['cum_freq'].mean()
	z = data['idiosincracy_index'].mean()

	df_aux = pd.DataFrame([[isocode[0], x,y,z]], columns=['file', 'word_types', 'cum_freq', 'idiosincracy_index'])
	df_avg=df_avg.append(df_aux)

#print(df_avg.describe())
df_isocodes=df_avg.iloc[:, 0:1] 
df_isocodes=df_isocodes.reset_index(drop=True)


df_avg.columns = range(df_avg.shape[1]) #remove header
df_avg = df_avg.iloc[: , 1:]  #remove first column

# perform a robust scaler transform of the dataset
trans = StandardScaler()
data = trans.fit_transform(df_avg)
# convert the array back to a dataframe
df_data= DataFrame(data)
df_avg_transformed=df_isocodes.join(df_data)
df_avg_transformed.rename(columns={0:'word_types',
                          1:'cum_freq',
                          2:'idiosincracy_index'}, 
                 inplace=True)
#df_avg_transformed.hist()

fig = plt.figure(figsize=(13.5, 13.5))
ax = fig.add_subplot(111, projection='3d')

xs = df_avg_transformed['word_types']
ys = df_avg_transformed['cum_freq']
zs = df_avg_transformed['idiosincracy_index']
labels=df_avg_transformed['file']

ax.set_xlabel('|W| Productivity',fontdict=dict(weight='bold'))
ax.set_ylabel('C. freq',fontdict=dict(weight='bold'))
ax.set_zlabel('Idiosyncrasy',fontdict=dict(weight='bold'))
#ax.set_xlim(-3, 3)
#ax.set_ylim(-2.5, 2.5)
#ax.set_zlim(-3,3)
#plt.zlim([-3, 3])
ax.scatter(xs, ys, zs, s=50, alpha=1, edgecolors='w')

for x, y, z, label in zip(xs, ys, zs, labels):
    ax.text(x, y, z, label,weight="book", size="large")
    
#plt.savefig("original_space.png")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
all_files = os.listdir(directory)

df_avg = pd.DataFrame(columns = ['file', 'word_types', 'cum_freq', 'idiosincracy_index'])

for n in all_files:
	inputcorpus=directory+n
	data = pd.read_csv(inputcorpus,  sep='\t')
	#print ("Processing"+n)

	fileparts=n.split(".")
	isocode=fileparts[0].split("-")

	x = data['word_types'].mean()
	y = data['cum_freq'].mean()
	z = data['idiosincracy_index'].mean()

	df_aux = pd.DataFrame([[isocode[0], x,y,z]], columns=['file', 'word_types', 'cum_freq', 'idiosincracy_index'])
	df_avg=df_avg.append(df_aux)

#print(df_avg.describe())
df_isocodes=df_avg.iloc[:, 0:1] 
df_isocodes=df_isocodes.reset_index(drop=True)


df_avg.columns = range(df_avg.shape[1]) #remove header
df_avg = df_avg.iloc[: , 1:]  #remove first column

# perform a robust scaler transform of the dataset
trans = StandardScaler()
data = trans.fit_transform(df_avg)
# convert the array back to a dataframe
df_data= DataFrame(data)
df_avg_transformed=df_isocodes.join(df_data)
df_avg_transformed.rename(columns={0:'word_types',
                          1:'cum_freq',
                          2:'idiosincracy_index'}, 
                 inplace=True)
#df_avg_transformed.hist()

#output=directory.replace('/', '')
#output=output.replace('tsv_', '')
#output=output+"_avgscaler"

#plt.savefig(output+".png")

  
df_avg_transformed.to_csv(output, index=False,)

fig = plt.figure(figsize=(13.6, 13.6))
ax = fig.add_subplot(111, projection='3d')

xs = df_avg_transformed['word_types']
ys = df_avg_transformed['cum_freq']
zs = df_avg_transformed['idiosincracy_index']
labels=df_avg_transformed['file']

ax.set_xlabel('|W| Productivity',fontdict=dict(weight='bold'))
ax.set_ylabel('C. freq',fontdict=dict(weight='bold'))
ax.set_zlabel('Idiosyncrasy',fontdict=dict(weight='bold'))
#ax.set_xlim(-3, 3)
#ax.set_ylim(-2.5, 2.5)
#ax.set_zlim(-3,3)
#plt.zlim([-3, 3])
img=ax.scatter(xs, ys, zs, c=xs, s=50, alpha=1, edgecolors='w', cmap="jet")# cmap='jet')

#for x, y, z, label in zip(xs, ys, zs, labels):
#    ax.text(x, y, z, label,weight="book", size="large")

######FIX for text colors:
colors=xs.tolist()
for x, y, z, label, color in zip(xs, ys, zs, labels, colors):
    if (color<=-1):
        ax.text(x, y, z, label,weight="book", size="large", color="#00009b", fontweight="medium")
    if (color>-1 and color<-0.4):
        ax.text(x, y, z, label,weight="book", size="large",  color="#0000cd", fontweight="medium")       
    if (color>=-0.4 and color<0):
        ax.text(x, y, z, label,weight="book", size="large",  color="#007dff", fontweight="medium")
    if (color>=0 and color<0.2):
        ax.text(x, y, z, label,weight="book", size="large",  color="#00b9ff", fontweight="medium")#, backgroundcolor="white", alpha=0.1)
    if (color>=0.2 and color<0.4):
        ax.text(x, y, z, label,weight="book", size="large",  color="#02e8f4", fontweight="medium")#, backgroundcolor="white", alpha=0.1)
    if (color>=0.4 and color<0.6):
        ax.text(x, y, z, label,weight="book", size="large",  color="#23ffd4", fontweight="medium")#, backgroundcolor="white", alpha=0.1)  
    if (color>=0.6 and color<1.1):
        ax.text(x, y, z, label,weight="book", size="large",  color="#5fffaa", fontweight="medium")#, backgroundcolor="white", alpha=0.1)
        
    if (color>=1.1 and color<2):
        ax.text(x, y, z, label,weight="book", size="large",  color="#baff3c", fontweight="medium")#, backgroundcolor="white", alpha=0.1)
        
    if (color>=2 and color<3):
        ax.text(x, y, z, label,weight="book", size="large",  color="#ff4300", fontweight="medium")#, backgroundcolor="white", alpha=0.1)
        
    if (color>3):
        ax.text(x, y, z, label,weight="book", size="large",  color="#800000", fontweight="medium")#, backgroundcolor="white", alpha=0.1)
        
            
#fig.colorbar(img)
cbar=plt.colorbar(img, fraction=0.026, pad=0.04)
#plt.savefig("original_space.png")
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # WALS

# %%
wals_lang=pd.read_csv('WALS/languages.csv',index_col=1)
wals_values=pd.read_csv('WALS/values.csv',index_col=0)

#bpe_partitions=pd.read_csv('corpusPBC_tok_avgscaler_avgscaler_regions.csv',index_col=0)
bpe_partitions=pd.read_csv(output,index_col=0).sort_index()

# %%
#We obtain the isocodes and extract form wals info only for those languages (and  that they are part of the Samples_100)
isocodes=bpe_partitions.index.tolist()
wals_lang_filtered=wals_lang.query('ISO_codes in @isocodes')
wals_lang_filtered=wals_lang_filtered.loc[wals_lang_filtered['Samples_100'] == True]
wals_lang_filtered=wals_lang_filtered.drop(['Samples_100','Samples_200'], 1)
#wals_lang_filtered.to_csv("extended_info.csv", index=False,)
wals_lang_filtered
#Kew and Jac missing, original csv  had to be modified

#Extracting the features:
feature="22A"
walscodes=wals_lang_filtered["ID"].tolist()
wals_values_filtered=wals_values.query('Language_ID in @walscodes')
wals_values_filtered=wals_values_filtered.loc[wals_values_filtered['Parameter_ID'] == feature]
wals_values_filtered
#renaming and merging:
wals_lang_filtered=wals_lang_filtered.rename(columns={"ID": "Language_ID"})
wals_lang_filtered

aux1=wals_values_filtered.merge(wals_lang_filtered, on="Language_ID")
aux1=aux1.drop(['Comment','Source_x','Example_ID','Source_y',], 1)
aux1=aux1.rename(columns={"ISO_codes": "file"})
aux1=aux1.set_index('file')
aux1

all_values=bpe_partitions.join(aux1) #What we need:
#all_values.to_csv(feature+".csv", index=False,)
#all_values

# %%
all_values
# Out:
#       word_types  cum_freq  idiosincracy_index Language_ID Parameter_ID  \
# file
# aey    -0.120245  0.382619            0.541143         ame          22A
# amp     1.017984  0.714560           -0.083476         ala          22A
# ape     0.293677  2.304998            0.844482         arp          22A
# apu     1.304904  1.416231           -0.286248         apu          22A
# arn     0.728671  0.674319            0.258006         map          22A
# arz     1.214466 -0.305182           -1.211587         aeg          22A
# bsn     1.429514  2.310988            0.488082         brs          22A
# cha    -0.105551 -0.337584           -0.602917         cha          22A
# deu    -0.257042 -0.299152           -0.045859         ger          22A
# dgz    -0.540659  0.524127            0.538014         dag          22A
# ell     0.019058 -0.374569           -0.399440         grk          22A
# eng    -0.936243 -0.454409            0.479059         eng          22A
# eus     0.137631 -0.564319           -0.955325         bsq          22A
# fij    -0.885442 -0.090709           -0.065847         fij          22A
# fin     0.472390 -0.545746           -0.945834         fin          22A
# fra    -0.189156 -0.528701           -0.861177         fre          22A
# gug    -0.227085 -0.490268           -0.294268         gua          22A
# hae     0.298803  0.166980           -0.612687         orh          22A
# hau    -0.780083 -0.752460           -0.460459         hau          22A
# hin    -1.114159 -1.243477            0.644028         hin          22A
# ind    -0.178107  0.798018            0.062625         ind          22A
# jac    -0.077531  0.908892            1.272946         jak          22A
# kal     3.246602 -0.118729           -1.416216         grw          22A
# kat     0.142187 -0.757365           -0.969069         geo          22A
# kew    -0.151340  0.749535            0.088267         kew          22A
# khk     0.081705 -0.649103           -0.845143         kha          22A
# kor    -1.211659 -2.410677           -0.961944         kor          22A
# laj    -0.907426 -0.961345           -0.210462         lan          22A
# mig    -0.044841  0.333453           -0.090682         mxc          22A
# mya    -1.291847  0.525213            3.170820         brm          22A
# mzh    -0.250891  0.197493            0.518813         wch          22A
# naq    -0.521979 -0.967818           -0.312361         kho          22A
# pes    -0.780196 -1.179396           -0.431042         prs          22A
# plt     0.104941  0.217272           -0.578374         mal          22A
# qvi     2.499857  1.891247           -0.825692         qim          22A
# rus     0.071909 -1.127537           -0.969903         rus          22A
# sag    -1.286380  0.224709            1.950634         san          22A
# spa    -0.389055 -0.680179           -0.467031         spa          22A
# swh     0.204378 -0.754953           -0.982824         swa          22A
# tgl    -0.191320  0.038779           -0.103738         tag          22A
# tha    -1.331713 -0.485364            2.175471         tha          22A
# tur     0.541074 -0.835315           -1.106702         tur          22A
# vie    -1.327498 -1.093446            1.628691         vie          22A
# xsu    -0.494073  1.613257            2.542130         snm          22A
# yad     2.528674  1.783629           -0.581683         yag          22A
# yaq     0.457697  1.252290            0.449845         yaq          22A
# yor    -1.204597 -1.020803            0.024934         yor          22A
#
#       Value Code_ID      Macroarea   Latitude   Longitude Glottocode  \
# file
# aey       4   22A-4      Papunesia  -5.250000  145.583333   amel1241
# amp       6   22A-6      Papunesia  -4.666667  143.333333   alam1246
# ape       3   22A-3      Papunesia  -3.466667  143.166667   buki1249
# apu       4   22A-4  South America  -9.000000  -67.000000   apur1254
# arn       5   22A-5  South America -38.000000  -72.000000   mapu1245
# arz       4   22A-4         Africa  30.000000   31.000000   egyp1253
# bsn       3   22A-3  South America  -0.166667  -70.666667   bara1380
# cha       4   22A-4      Papunesia  13.450000  144.750000   cham1312
# deu       2   22A-2        Eurasia  52.000000   10.000000   stan1295
# dgz       5   22A-5      Papunesia -10.000000  149.333333   daga1275
# ell       3   22A-3        Eurasia  39.000000   22.000000   mode1248
# eng       2   22A-2        Eurasia  52.000000    0.000000   stan1293
# eus       3   22A-3        Eurasia  43.000000   -3.000000   basq1248
# fij       4   22A-4      Papunesia -17.833333  178.000000   fiji1243
# fin       2   22A-2        Eurasia  62.000000   25.000000   finn1318
# fra       3   22A-3        Eurasia  48.000000    2.000000   stan1290
# gug       3   22A-3  South America -26.000000  -56.000000   para1311
# hae       4   22A-4         Africa   9.000000   42.000000   east2652
# hau       4   22A-4         Africa  12.000000    7.000000   haus1257
# hin       2   22A-2        Eurasia  25.000000   77.000000   hind1269
# ind       3   22A-3      Papunesia   0.000000  106.000000   indo1316
# jac       3   22A-3  North America  15.666667  -91.666667        NaN
# kal       3   22A-3        Eurasia  64.000000  -51.000000   kala1399
# kat       5   22A-5        Eurasia  42.000000   44.000000   nucl1302
# kew       4   22A-4      Papunesia  -6.500000  143.833333   kewa1250
# khk       2   22A-2        Eurasia  47.000000  105.000000   halh1238
# kor       4   22A-4        Eurasia  37.500000  128.000000   kore1280
# laj       4   22A-4         Africa   2.166667   33.000000   lang1324
# mig       3   22A-3  North America  17.050000  -97.583333   sanm1295
# mya       2   22A-2        Eurasia  21.000000   96.000000   nucl1310
# mzh       2   22A-2  South America -22.500000  -62.583333   wich1264
# naq       4   22A-4         Africa -25.500000   18.000000   nama1264
# pes       3   22A-3        Eurasia  32.000000   54.000000   west2369
# plt       3   22A-3         Africa -20.000000   47.000000   plat1254
# qvi       5   22A-5  South America   0.333333  -78.000000   imba1240
# rus       3   22A-3        Eurasia  56.000000   38.000000   russ1263
# sag       1   22A-1         Africa   5.000000   18.000000   sang1328
# spa       3   22A-3        Eurasia  40.000000   -4.000000   stan1288
# swh       3   22A-3         Africa  -6.500000   39.000000   swah1253
# tgl       2   22A-2      Papunesia  15.000000  121.000000   taga1270
# tha       2   22A-2        Eurasia  16.000000  101.000000   thai1261
# tur       4   22A-4        Eurasia  39.000000   35.000000   nucl1301
# vie       1   22A-1        Eurasia  10.500000  106.500000   viet1252
# xsu       3   22A-3  South America   4.500000  -64.666667   sanu1240
# yad       6   22A-6  South America  -3.500000  -72.000000   yagu1244
# yaq       3   22A-3  North America  27.500000 -110.250000   yaqu1251
# yor       4   22A-4         Africa   8.000000    4.333333   yoru1245
#
#      ISO639P3code            Family                  Subfamily  \
# file
# aey           aey  Trans-New Guinea                        NaN
# amp           amp             Sepik                        NaN
# ape           ape        Torricelli                        NaN
# apu           apu          Arawakan                        NaN
# arn           arn        Araucanian                        NaN
# arz           arz      Afro-Asiatic                        NaN
# bsn           bsn          Tucanoan                        NaN
# cha           cha      Austronesian                        NaN
# deu           deu     Indo-European                        NaN
# dgz           dgz             Dagan                        NaN
# ell           ell     Indo-European                        NaN
# eng           eng     Indo-European                        NaN
# eus           eus               NaN                        NaN
# fij           fij      Austronesian  Eastern Malayo-Polynesian
# fin           fin            Uralic                Finno-Ugric
# fra           fra     Indo-European                        NaN
# gug           gug            Tupian                        NaN
# hae           hae      Afro-Asiatic                   Cushitic
# hau           hau      Afro-Asiatic                     Chadic
# hin           hin     Indo-European                        NaN
# ind           ind      Austronesian                        NaN
# jac           NaN             Mayan                        NaN
# kal           kal      Eskimo-Aleut                        NaN
# kat           kat        Kartvelian                        NaN
# kew           NaN  Trans-New Guinea                        NaN
# khk           khk            Altaic                        NaN
# kor           kor               NaN                        NaN
# laj           laj   Eastern Sudanic                        NaN
# mig           mig      Oto-Manguean                        NaN
# mya           mya      Sino-Tibetan              Tibeto-Burman
# mzh           mzh          Matacoan                        NaN
# naq           naq        Khoe-Kwadi                        NaN
# pes           pes     Indo-European                        NaN
# plt           plt      Austronesian                        NaN
# qvi           qvi          Quechuan                        NaN
# rus           rus     Indo-European                        NaN
# sag           sag       Niger-Congo             Adamawa-Ubangi
# spa           spa     Indo-European                        NaN
# swh           swh       Niger-Congo                Benue-Congo
# tgl           tgl      Austronesian                        NaN
# tha           tha         Tai-Kadai                        NaN
# tur           tur            Altaic                        NaN
# vie           vie    Austro-Asiatic                  Mon-Khmer
# xsu           xsu           Yanomam                        NaN
# yad           yad       Peba-Yaguan                        NaN
# yaq           yaq       Uto-Aztecan                        NaN
# yor           yor       Niger-Congo                Benue-Congo
#
#                            Genus GenusIcon Country_ID
# file
# aey                       Madang   cff6600         PG
# amp                   Sepik Hill   dff66ff         PG
# ape               Kombio-Arapesh   c0000dd         PG
# apu                        Purus   c990099         BR
# arn                   Araucanian   daa0000         CL
# arz                      Semitic   cdd0000         EG
# bsn                     Tucanoan   ddd0000         CO
# cha                     Chamorro   t9999ff         GU
# deu                     Germanic   cff4400   CH DE AT
# dgz                        Dagan   sdd0000         PG
# ell                        Greek   cffffcc         GR
# eng                     Germanic   cff4400      IE GB
# eus                          NaN   d990099      FR ES
# fij                      Oceanic   c0000dd         FJ
# fin                       Finnic   f9999ff         FI
# fra                      Romance   cffcc00      CH FR
# gug                 Tupi-Guaraní   dffff00         PY
# hae        Lowland East Cushitic   cff6600         ET
# hau                  West Chadic   c9999ff      NG NE
# hin                        Indic   cff6600         IN
# ind              Malayo-Sumbawan   d990099         ID
# jac                        Mayan   tff6600         GT
# kal                       Eskimo   t990099         GL
# kat                   Kartvelian   f000000         GE
# kew                        Engan   caa0000         PG
# khk                     Mongolic   d009900         MN
# kor                          NaN   fffcc00      KR KP
# laj                      Nilotic   sffcc00         UG
# mig                     Mixtecan   tff4400         MX
# mya                 Burmese-Lolo   f9999ff         MM
# mzh                     Matacoan   tff4400      BO AR
# naq                   Khoe-Kwadi   f9999ff        NaN
# pes                      Iranian   cff66ff         IR
# plt                       Barito   t990099         MG
# qvi                     Quechuan   cffffcc         EC
# rus                       Slavic   cffff00         RU
# sag                       Ubangi   dffff00         CF
# spa                      Romance   cffcc00         ES
# swh                      Bantoid   d0000dd         TZ
# tgl   Greater Central Philippine   cffffcc         PH
# tha                      Kam-Tai   sff66ff         TH
# tur                       Turkic   d0000dd         TR
# vie                   Viet-Muong   sffffcc         VN
# xsu                      Yanomam   t990099      BR VR
# yad                  Peba-Yaguan   c009900         PE
# yaq                       Cahita   fffffcc         MX
# yor                       Defoid   f990099      NG BJ

# %%
#We obtain the isocodes and extract form wals info only for those languages (and  that they are part of the Samples_100)
isocodes=bpe_partitions.index.tolist()
wals_lang_filtered=wals_lang.query('ISO_codes in @isocodes')
wals_lang_filtered=wals_lang_filtered.loc[wals_lang_filtered['Samples_100'] == True]
wals_lang_filtered=wals_lang_filtered.drop(['Samples_100','Samples_200'], 1)
#wals_lang_filtered.to_csv("extended_info.csv", index=False,)
wals_lang_filtered
#Kew and Jac missing, original csv  had to be modified

featuresofinterest=["20A", "22A", "26A", "27A", "28A", "29A", "30A", "33A", "34A", "37A", "38A", "49A", "51A", "57A", "59A", "65A", "66A", "67A", "69A", "70A", "73A", "74A", "75A", "78A", "94A", "101A", "102A", "111A", "112A"]
walscodes=wals_lang_filtered["ID"].tolist()

all_features=bpe_partitions
for feature in featuresofinterest:

    
    wals_values_filtered=wals_values.query('Language_ID in @walscodes')
    wals_values_filtered=wals_values_filtered.loc[wals_values_filtered['Parameter_ID'] == feature]
    wals_values_filtered
    #renaming and merging:
    wals_lang_filtered=wals_lang_filtered.rename(columns={"ID": "Language_ID"})
    wals_lang_filtered

    aux1=wals_values_filtered.merge(wals_lang_filtered, on="Language_ID")
    aux1=aux1.drop(['Comment','Source_x','Example_ID','Source_y',], 1)
    aux1=aux1.rename(columns={"ISO_codes": "file"})
    aux1=aux1.set_index('file')
    aux1

    all_values=bpe_partitions.join(aux1) #What we need for each feature
    
    all_features=all_features.join(aux1['Value'])
    all_features=all_features.rename(columns={"Value": feature}) #all features together
        
    #all_values.to_csv(feature+".csv", index=False,)
    
    #print(feature, all_values['Parameter_ID'].count())

#all_values['Value']
#all_features.to_csv("allfeatures.csv", index=False,)

# %%
reduced_list_features=["49A", "69A", "70A", "112A", "22A", "26A", "28A", "29A", "59A", "65A", "66A", "67A", "78A", "102A"]
extra_reduced_list_features=["22A", "26A", "28A", "29A", "59A", "65A", "66A", "67A", "78A", "102A"]
special_list_features=["22A", "26A","49A"]

#Transformations:
#uncomment just if you want ALL original from chris:
#some_features=all_features[["22A", "26A", "27A", "28A", "29A", "30A", "33A", "34A", "37A", "38A", "49A", "51A", "57A", "59A", "65A", "66A", "67A", "69A", "70A", "73A", "74A", "75A", "78A", "94A", "101A", "102A", "111A", "112A"]]
#some_features=all_features[["22A", "26A", "27A", "28A", "29A", "30A", "33A", "37A", "49A", "51A", "59A", "65A", "66A", "67A", "69A", "70A", "73A", "74A", "75A", "78A", "94A", "101A", "102A", "111A", "112A"]]
#some_features=all_features[["22A", "26A", "28A", "29A", "33A", "49A", "51A", "59A", "65A", "66A", "67A", "69A", "70A", "73A", "75A", "78A", "102A", "111A", "112A"]]
#some_features=all_features[["22A", "26A", "28A", "29A", "49A", "51A", "59A", "65A", "66A", "67A", "69A", "70A", "73A", "78A", "102A", "112A"]]

some_features=all_features[["20A", "49A", "69A", "70A", "112A", "22A", "26A", "28A", "29A", "59A", "65A", "66A", "67A", "78A", "102A"]]  #Adding 20A
reduced_some_features=all_features[["22A", "26A", "28A", "29A", "59A", "65A", "66A", "67A", "78A", "102A"]]

#substitute nan by zero:
some_features=some_features.fillna(0)
special_features=some_features[["22A", "26A","49A"]]

# %%
some_features
# Out:
#       20A  49A  69A  70A  112A  22A  26A  28A  29A  59A  65A  66A  67A  78A  \
# file
# aey     1  1.0  2.0  5.0   2.0    4    2    1    2    4    2    2    1    1
# amp     1  7.0  2.0  1.0   2.0    6    2    1    3    1    1    2    1    1
# ape     1  1.0  1.0  1.0   2.0    3    5    1    3    1    2    4    1    1
# apu     1  9.0  2.0  3.0   2.0    4    4    1    3    1    2    4    1    2
# arn     1  2.0  2.0  1.0   1.0    5    2    1    3    1    2    4    1    1
# arz     6  1.0  4.0  1.0   2.0    4    3    1    2    1    1    1    1    1
# bsn     1  2.0  2.0  4.0   1.0    3    2    1    3    2    2    2    2    3
# cha     7  1.0  0.0  0.0   2.0    4    1    1    3    1    1    4    2    4
# deu     1  4.0  2.0  2.0   2.0    2    2    3    2    1    2    1    2    5
# dgz     1  9.0  2.0  1.0   2.0    5    2    1    2    2    2    1    1    1
# ell     1  3.0  2.0  1.0   2.0    3    2    3    3    1    1    1    2    1
# eng     1  2.0  2.0  5.0   2.0    2    2    2    2    1    2    1    2    1
# eus     1  8.0  4.0  1.0   2.0    3    4    2    3    1    1    1    1    4
# fij     2  1.0  5.0  5.0   0.0    4    1    2    1    1    2    1    2    1
# fin     1  8.0  2.0  1.0   3.0    2    2    3    3    1    2    1    2    5
# fra     1  1.0  2.0  2.0   2.0    3    2    3    2    1    1    1    1    5
# gug     1  1.0  5.0  2.0   6.0    3    6    1    3    1    2    1    1    4
# hae     1  6.0  2.0  1.0   6.0    4    2    2    2    2    1    1    2    1
# hau     2  1.0  5.0  2.0   2.0    4    1    4    1    1    2    4    2    1
# hin     1  0.0  2.0  1.0   2.0    2    2    3    2    1    1    1    1    1
# ind     2  1.0  2.0  5.0   4.0    3    2    1    1    1    2    4    2    1
# jac     1  1.0  4.0  1.0   2.0    3    6    1    3    1    1    4    2    4
# kal     1  7.0  2.0  1.0   1.0    3    2    2    3    1    2    4    1    2
# kat     1  6.0  2.0  5.0   2.0    5    3    3    3    1    1    1    1    6
# kew     1  6.0  2.0  1.0   1.0    4    2    1    2    1    2    2    1    2
# khk     1  7.0  2.0  4.0   1.0    2    2    4    1    1    2    1    2    6
# kor     1  6.0  2.0  4.0   2.0    4    2    1    1    1    1    1    2    2
# laj     3  1.0  3.0  1.0   2.0    4    4    1    2    2    1    4    2    1
# mig     1  1.0  1.0  4.0   2.0    3    6    1    3    1    1    4    1    1
# mya     1  7.0  2.0  5.0   6.0    2    2    1    1    1    2    4    2    1
# mzh     2  1.0  2.0  1.0   2.0    2    4    1    3    3    2    2    1    1
# naq     7  2.0  5.0  5.0   2.0    4    2    1    2    2    1    2    2    1
# pes     1  2.0  4.0  2.0   1.0    3    3    1    3    1    1    1    2    3
# plt     1  1.0  1.0  4.0   2.0    3    1    1    3    1    1    4    2    1
# qvi     1  7.0  2.0  1.0   2.0    5    2    4    3    1    2    1    1    2
# rus     1  6.0  4.0  1.0   2.0    3    2    3    3    1    1    1    2    1
# sag     1  1.0  5.0  5.0   2.0    1    6    1    3    1    2    4    2    1
# spa     1  1.0  2.0  1.0   2.0    3    2    3    2    1    1    1    1    1
# swh     1  1.0  1.0  1.0   1.0    3    5    1    2    1    2    1    1    1
# tgl     1  1.0  1.0  1.0   2.0    2    1    1    1    1    1    4    1    4
# tha     7  1.0  5.0  5.0   3.0    2    1    1    1    1    2    4    2    1
# tur     1  6.0  2.0  1.0   1.0    4    2    4    3    1    1    1    1    3
# vie     2  1.0  5.0  5.0   4.0    1    1    1    1    1    2    4    2    1
# xsu     1  2.0  5.0  5.0   3.0    3    1    1    1    2    2    2    2    6
# yad     1  9.0  2.0  5.0   2.0    6    2    1    1    1    1    3    2    1
# yaq     1  2.0  2.0  1.0   2.0    3    2    2    1    1    1    1    1    2
# yor     4  1.0  5.0  5.0   4.0    4    1    4    1    1    2    4    2    1
#
#       102A
# file
# aey      5
# amp      5
# ape      5
# apu      5
# arn      5
# arz      5
# bsn      2
# cha      2
# deu      2
# dgz      5
# ell      5
# eng      2
# eus      5
# fij      5
# fin      2
# fra      2
# gug      5
# hae      2
# hau      1
# hin      2
# ind      3
# jac      5
# kal      5
# kat      5
# kew      2
# khk      1
# kor      1
# laj      5
# mig      2
# mya      1
# mzh      5
# naq      3
# pes      5
# plt      1
# qvi      5
# rus      2
# sag      1
# spa      5
# swh      5
# tgl      1
# tha      1
# tur      2
# vie      1
# xsu      1
# yad      5
# yaq      1
# yor      1

# %% [markdown]
# CLUSTERING

# %%
caption="normal"
dataset=some_features
clusters=4
#Center and scaling:
trans = StandardScaler()
data = trans.fit_transform(dataset)
##################Kclustering:#######################################3
scores={}
for x in range(600):


    #km = sklearn.cluster.KMeans(n_clusters=clusters, init='k-means++', algorithm="full")
    km = sklearn.cluster.KMeans(n_clusters=clusters, random_state=x, init='k-means++', algorithm="full")
    #km=sklearn.cluster.AgglomerativeClustering(n_clusters=clusters)
    #km=sklearn.cluster.SpectralClustering(n_clusters=clusters, assign_labels='discretize', random_state=0)
    #km = sklearn.cluster.AffinityPropagation(preference=-50, random_state=0)
    km.fit(data)

    # Get cluster assignment labels
    labels = km.labels_
    # Format results as a DataFrame
    results = pd.DataFrame([dataset.index,labels]).T  

    #Join the clustering with the info for each language
    #clustered=pd.concat([dataset, results],  axis=1)

    results=results.rename(columns={1: "cluster", 0:"file"})
    results=results.set_index("file")
   


    ####Silhouette score
    X = all_values[['word_types', 'cum_freq', 'idiosincracy_index']]
    S=metrics.silhouette_score(X, km.labels_, metric="sqeuclidean")   #braycurtis
    #S=metrics.silhouette_score(data, km.labels_, metric="sqeuclidean")   #braycurtis  #over WALS (Expected higher values)
    scores[x]=S
    #print(x,S)

# %%
max_seed = max(scores, key=scores.get)
mean_seeds=res = sum(scores.values()) / len(scores)
print(max_seed, scores[max_seed])
print("mean", mean_seeds)
#max_seed=574
# Out:
# 173 0.11819002209656741
# mean -0.049121813720889765

# %%
caption="normal"
dataset=some_features
clusters=4
#Center and scaling:
trans = StandardScaler()
data = trans.fit_transform(dataset)
##################Kclustering:#######################################3
#km = sklearn.cluster.KMeans(n_clusters=clusters, init='k-means++', algorithm="full")
km = sklearn.cluster.KMeans(n_clusters=clusters, random_state=max_seed, init='k-means++', algorithm="full")  #299
#km=sklearn.cluster.AgglomerativeClustering(n_clusters=clusters)
#km=sklearn.cluster.SpectralClustering(n_clusters=clusters, assign_labels='discretize', random_state=0)
#km = sklearn.cluster.AffinityPropagation(preference=-50, random_state=0)
km.fit(data)

# Get cluster assignment labels
labels = km.labels_
# Format results as a DataFrame
results = pd.DataFrame([dataset.index,labels]).T  

#Join the clustering with the info for each language
#clustered=pd.concat([dataset, results],  axis=1)

results=results.rename(columns={1: "cluster", 0:"file"})
results=results.set_index("file")
#results.to_csv("features"+caption+"clustering_k"+str(clusters)+".csv", index=True,)

######################Plotting:###############################################################
import matplotlib.colors

colors_custom=[ "#8000FF","aqua","#FDD835","green"]

cmap= matplotlib.colors.ListedColormap(colors_custom)
cmap.set_under("crimson")
cmap.set_over("w")

colors=results["cluster"].tolist() #converting nan to zeros
labels=results.index.tolist() #languages

fig = plt.figure(figsize=(13, 13))
ax = fig.add_subplot(111, projection='3d')

xs = all_values['word_types']
ys = all_values['cum_freq']
zs = all_values['idiosincracy_index']


ax.set_xlabel('|W| Productivity',fontdict=dict(weight='bold'))
ax.set_ylabel('C. freq',fontdict=dict(weight='bold'))
ax.set_zlabel('Idiosyncrasy',fontdict=dict(weight='bold'))

img=ax.scatter(xs, ys, zs, s=50, alpha=0.6, edgecolors='w', c=colors,cmap=cmap)  #cmap gist_rainbow"
ax.set_title("Clustering WALS based "+ caption)
for x, y, z, label, color in zip(xs, ys, zs, labels, colors):
    if (color==0):
        ax.text(x, y, z, label,weight="book", size="large", color="#8000FF", fontweight="medium")
    if (color==1):
        ax.text(x, y, z, label,weight="book", size="large",  color="aqua", fontweight="medium")       
    if (color==2):
        ax.text(x, y, z, label,weight="book", size="large",  color="#FDD835", fontweight="medium")
    if (color==3):
        ax.text(x, y, z, label,weight="book", size="large",  color="green", fontweight="medium")#, backgroundcolor="white", alpha=0.1)
cbar=fig.colorbar(img, fraction=0.026, pad=0.04, ticks=np.linspace(0,clusters-1,clusters))  #discrete colorbar
tick_font_size = 15
#cbar.ax.tick_params(labelsize=tick_font_size)


plt.savefig(output+"clustering_k"+str(clusters)+".png")


####Silhouette score
X = all_values[['word_types', 'cum_freq', 'idiosincracy_index']]
S=metrics.silhouette_score(X, km.labels_, metric="sqeuclidean")   #braycurtis
#S=metrics.silhouette_score(data, km.labels_, metric="sqeuclidean")   #braycurtis
print(S)

#[‘braycurtis’, ‘canberra’, ‘chebyshev’, ‘correlation’, ‘dice’, ‘hamming’, ‘jaccard’, ‘kulsinski’, ‘mahalanobis’, ‘minkowski’, ‘rogerstanimoto’, ‘russellrao’, ‘seuclidean’, ‘sokalmichener’, ‘sokalsneath’, ‘sqeuclidean’, ‘yule’]
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 0.11819002209656741

# %%
all_values
# Out:
#       word_types  cum_freq  idiosincracy_index Language_ID Parameter_ID  \
# file
# kat     0.142187 -0.757365           -0.969069         geo         112A
# tur     0.541074 -0.835315           -1.106702         tur         112A
# kew    -0.151340  0.749535            0.088267         kew         112A
# sag    -1.286380  0.224709            1.950634         san         112A
# mig    -0.044841  0.333453           -0.090682         mxc         112A
# plt     0.104941  0.217272           -0.578374         mal         112A
# ape     0.293677  2.304998            0.844482         arp         112A
# rus     0.071909 -1.127537           -0.969903         rus         112A
# yaq     0.457697  1.252290            0.449845         yaq         112A
# amp     1.017984  0.714560           -0.083476         ala         112A
# deu    -0.257042 -0.299152           -0.045859         ger         112A
# tgl    -0.191320  0.038779           -0.103738         tag         112A
# fij    -0.885442 -0.090709           -0.065847         NaN          NaN
# arn     0.728671  0.674319            0.258006         map         112A
# tha    -1.331713 -0.485364            2.175471         tha         112A
# swh     0.204378 -0.754953           -0.982824         swa         112A
# eus     0.137631 -0.564319           -0.955325         bsq         112A
# ind    -0.178107  0.798018            0.062625         ind         112A
# kor    -1.211659 -2.410677           -0.961944         kor         112A
# aey    -0.120245  0.382619            0.541143         ame         112A
# khk     0.081705 -0.649103           -0.845143         kha         112A
# xsu    -0.494073  1.613257            2.542130         snm         112A
# mya    -1.291847  0.525213            3.170820         brm         112A
# yad     2.528674  1.783629           -0.581683         yag         112A
# pes    -0.780196 -1.179396           -0.431042         prs         112A
# arz     1.214466 -0.305182           -1.211587         aeg         112A
# dgz    -0.540659  0.524127            0.538014         dag         112A
# mzh    -0.250891  0.197493            0.518813         wch         112A
# qvi     2.499857  1.891247           -0.825692         qim         112A
# bsn     1.429514  2.310988            0.488082         brs         112A
# ell     0.019058 -0.374569           -0.399440         grk         112A
# laj    -0.907426 -0.961345           -0.210462         lan         112A
# yor    -1.204597 -1.020803            0.024934         yor         112A
# jac    -0.077531  0.908892            1.272946         jak         112A
# gug    -0.227085 -0.490268           -0.294268         gua         112A
# fin     0.472390 -0.545746           -0.945834         fin         112A
# fra    -0.189156 -0.528701           -0.861177         fre         112A
# spa    -0.389055 -0.680179           -0.467031         spa         112A
# cha    -0.105551 -0.337584           -0.602917         cha         112A
# hau    -0.780083 -0.752460           -0.460459         hau         112A
# apu     1.304904  1.416231           -0.286248         apu         112A
# kal     3.246602 -0.118729           -1.416216         grw         112A
# hin    -1.114159 -1.243477            0.644028         hin         112A
# vie    -1.327498 -1.093446            1.628691         vie         112A
# naq    -0.521979 -0.967818           -0.312361         kho         112A
# eng    -0.936243 -0.454409            0.479059         eng         112A
# hae     0.298803  0.166980           -0.612687         orh         112A
#
#       Value Code_ID      Macroarea   Latitude   Longitude Glottocode  \
# file
# kat     2.0  112A-2        Eurasia  42.000000   44.000000   nucl1302
# tur     1.0  112A-1        Eurasia  39.000000   35.000000   nucl1301
# kew     1.0  112A-1      Papunesia  -6.500000  143.833333   kewa1250
# sag     2.0  112A-2         Africa   5.000000   18.000000   sang1328
# mig     2.0  112A-2  North America  17.050000  -97.583333   sanm1295
# plt     2.0  112A-2         Africa -20.000000   47.000000   plat1254
# ape     2.0  112A-2      Papunesia  -3.466667  143.166667   buki1249
# rus     2.0  112A-2        Eurasia  56.000000   38.000000   russ1263
# yaq     2.0  112A-2  North America  27.500000 -110.250000   yaqu1251
# amp     2.0  112A-2      Papunesia  -4.666667  143.333333   alam1246
# deu     2.0  112A-2        Eurasia  52.000000   10.000000   stan1295
# tgl     2.0  112A-2      Papunesia  15.000000  121.000000   taga1270
# fij     NaN     NaN            NaN        NaN         NaN        NaN
# arn     1.0  112A-1  South America -38.000000  -72.000000   mapu1245
# tha     3.0  112A-3        Eurasia  16.000000  101.000000   thai1261
# swh     1.0  112A-1         Africa  -6.500000   39.000000   swah1253
# eus     2.0  112A-2        Eurasia  43.000000   -3.000000   basq1248
# ind     4.0  112A-4      Papunesia   0.000000  106.000000   indo1316
# kor     2.0  112A-2        Eurasia  37.500000  128.000000   kore1280
# aey     2.0  112A-2      Papunesia  -5.250000  145.583333   amel1241
# khk     1.0  112A-1        Eurasia  47.000000  105.000000   halh1238
# xsu     3.0  112A-3  South America   4.500000  -64.666667   sanu1240
# mya     6.0  112A-6        Eurasia  21.000000   96.000000   nucl1310
# yad     2.0  112A-2  South America  -3.500000  -72.000000   yagu1244
# pes     1.0  112A-1        Eurasia  32.000000   54.000000   west2369
# arz     2.0  112A-2         Africa  30.000000   31.000000   egyp1253
# dgz     2.0  112A-2      Papunesia -10.000000  149.333333   daga1275
# mzh     2.0  112A-2  South America -22.500000  -62.583333   wich1264
# qvi     2.0  112A-2  South America   0.333333  -78.000000   imba1240
# bsn     1.0  112A-1  South America  -0.166667  -70.666667   bara1380
# ell     2.0  112A-2        Eurasia  39.000000   22.000000   mode1248
# laj     2.0  112A-2         Africa   2.166667   33.000000   lang1324
# yor     4.0  112A-4         Africa   8.000000    4.333333   yoru1245
# jac     2.0  112A-2  North America  15.666667  -91.666667        NaN
# gug     6.0  112A-6  South America -26.000000  -56.000000   para1311
# fin     3.0  112A-3        Eurasia  62.000000   25.000000   finn1318
# fra     2.0  112A-2        Eurasia  48.000000    2.000000   stan1290
# spa     2.0  112A-2        Eurasia  40.000000   -4.000000   stan1288
# cha     2.0  112A-2      Papunesia  13.450000  144.750000   cham1312
# hau     2.0  112A-2         Africa  12.000000    7.000000   haus1257
# apu     2.0  112A-2  South America  -9.000000  -67.000000   apur1254
# kal     1.0  112A-1        Eurasia  64.000000  -51.000000   kala1399
# hin     2.0  112A-2        Eurasia  25.000000   77.000000   hind1269
# vie     4.0  112A-4        Eurasia  10.500000  106.500000   viet1252
# naq     2.0  112A-2         Africa -25.500000   18.000000   nama1264
# eng     2.0  112A-2        Eurasia  52.000000    0.000000   stan1293
# hae     6.0  112A-6         Africa   9.000000   42.000000   east2652
#
#      ISO639P3code            Family       Subfamily  \
# file
# kat           kat        Kartvelian             NaN
# tur           tur            Altaic             NaN
# kew           NaN  Trans-New Guinea             NaN
# sag           sag       Niger-Congo  Adamawa-Ubangi
# mig           mig      Oto-Manguean             NaN
# plt           plt      Austronesian             NaN
# ape           ape        Torricelli             NaN
# rus           rus     Indo-European             NaN
# yaq           yaq       Uto-Aztecan             NaN
# amp           amp             Sepik             NaN
# deu           deu     Indo-European             NaN
# tgl           tgl      Austronesian             NaN
# fij           NaN               NaN             NaN
# arn           arn        Araucanian             NaN
# tha           tha         Tai-Kadai             NaN
# swh           swh       Niger-Congo     Benue-Congo
# eus           eus               NaN             NaN
# ind           ind      Austronesian             NaN
# kor           kor               NaN             NaN
# aey           aey  Trans-New Guinea             NaN
# khk           khk            Altaic             NaN
# xsu           xsu           Yanomam             NaN
# mya           mya      Sino-Tibetan   Tibeto-Burman
# yad           yad       Peba-Yaguan             NaN
# pes           pes     Indo-European             NaN
# arz           arz      Afro-Asiatic             NaN
# dgz           dgz             Dagan             NaN
# mzh           mzh          Matacoan             NaN
# qvi           qvi          Quechuan             NaN
# bsn           bsn          Tucanoan             NaN
# ell           ell     Indo-European             NaN
# laj           laj   Eastern Sudanic             NaN
# yor           yor       Niger-Congo     Benue-Congo
# jac           NaN             Mayan             NaN
# gug           gug            Tupian             NaN
# fin           fin            Uralic     Finno-Ugric
# fra           fra     Indo-European             NaN
# spa           spa     Indo-European             NaN
# cha           cha      Austronesian             NaN
# hau           hau      Afro-Asiatic          Chadic
# apu           apu          Arawakan             NaN
# kal           kal      Eskimo-Aleut             NaN
# hin           hin     Indo-European             NaN
# vie           vie    Austro-Asiatic       Mon-Khmer
# naq           naq        Khoe-Kwadi             NaN
# eng           eng     Indo-European             NaN
# hae           hae      Afro-Asiatic        Cushitic
#
#                            Genus GenusIcon Country_ID
# file
# kat                   Kartvelian   f000000         GE
# tur                       Turkic   d0000dd         TR
# kew                        Engan   caa0000         PG
# sag                       Ubangi   dffff00         CF
# mig                     Mixtecan   tff4400         MX
# plt                       Barito   t990099         MG
# ape               Kombio-Arapesh   c0000dd         PG
# rus                       Slavic   cffff00         RU
# yaq                       Cahita   fffffcc         MX
# amp                   Sepik Hill   dff66ff         PG
# deu                     Germanic   cff4400   CH DE AT
# tgl   Greater Central Philippine   cffffcc         PH
# fij                          NaN       NaN        NaN
# arn                   Araucanian   daa0000         CL
# tha                      Kam-Tai   sff66ff         TH
# swh                      Bantoid   d0000dd         TZ
# eus                          NaN   d990099      FR ES
# ind              Malayo-Sumbawan   d990099         ID
# kor                          NaN   fffcc00      KR KP
# aey                       Madang   cff6600         PG
# khk                     Mongolic   d009900         MN
# xsu                      Yanomam   t990099      BR VR
# mya                 Burmese-Lolo   f9999ff         MM
# yad                  Peba-Yaguan   c009900         PE
# pes                      Iranian   cff66ff         IR
# arz                      Semitic   cdd0000         EG
# dgz                        Dagan   sdd0000         PG
# mzh                     Matacoan   tff4400      BO AR
# qvi                     Quechuan   cffffcc         EC
# bsn                     Tucanoan   ddd0000         CO
# ell                        Greek   cffffcc         GR
# laj                      Nilotic   sffcc00         UG
# yor                       Defoid   f990099      NG BJ
# jac                        Mayan   tff6600         GT
# gug                 Tupi-Guaraní   dffff00         PY
# fin                       Finnic   f9999ff         FI
# fra                      Romance   cffcc00      CH FR
# spa                      Romance   cffcc00         ES
# cha                     Chamorro   t9999ff         GU
# hau                  West Chadic   c9999ff      NG NE
# apu                        Purus   c990099         BR
# kal                       Eskimo   t990099         GL
# hin                        Indic   cff6600         IN
# vie                   Viet-Muong   sffffcc         VN
# naq                   Khoe-Kwadi   f9999ff        NaN
# eng                     Germanic   cff4400      IE GB
# hae        Lowland East Cushitic   cff6600         ET
